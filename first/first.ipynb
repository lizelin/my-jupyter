# %%
msg = "hello world!"
print(msg)
# Out:
# hello world!

# %%
msg = "hello world!"
print(msg)
# Out:
# hello world!

# %%
msg = "hello again!"
print(msg)
# Out:
# hello again!

# %%
print('run')
# Out:
# run
